# %%
print("hello world")
# Out:
# hello world

# %%
import requests
from bs4 import BeautifulSoup

# %%
about_it_url = 'https://www.nitrr.ac.in/aboutit.php'
about_it_html = requests.get(about_it_url).text
soup = BeautifulSoup(about_it_html, "html.parser")

# %%
print("table" in about_it_html)
# Out:
# True

# %%
tables = soup.find_all('table')
for i, table in enumerate(tables, start=1):
    if not table:
        continue
    if 'Faculty' in table.get_text(strip=True):
        print(i)
    rows = table.find_all('tr')
    for row in rows:
        if not row:
            continue
        cells = row.find_all(['td', 'th'])
        if not cells:
            continue
        for cell in cells:
            txt = cell.get_text(strip=True)
# Out:
# 20
# 22

# %%
def get_faculty_table_indices(tables) -> list:
    res = []
    for i, table in enumerate(tables):
        if not table:
            continue
        if 'Qualification' in table.get_text(strip=True):
            res.append(i)
    return res

# %%
def extract_faculty_info(url: str) -> dict:
    html = requests.get(url).text
    soup = BeautifulSoup(html, "html.parser")
    print(f'got data from url {url}')

    tables = soup.find_all('table')
    fac_indices = get_faculty_table_indices(tables)

    if not fac_indices:
        print(f'no faculty table indices found for url {url}')
        return

    print(f'found {len(fac_indices)} facutly tables')

    res = []
    data_columns = []
    for idx in fac_indices:
        table = tables[idx]
        rows = table.find_all('tr')
        if not rows:
            print(f'no rows in table {idx}')
            continue
        found = False
        for row in rows:
            if 'Name' in row.get_text(strip=True):
                found = True
                print(f'found heading column for table {idx}')
                data_columns = [cell.get_text(strip=True) for cell in row.find_all(['td', 'th'])]
                continue
            if not found:
                continue
            cells = row.find_all('td')
            if len(data_columns) != len(cells):
                print(f'len of data_columns: {len(data_columns)} != len of cells ({len(cells)}) of table {idx}. Skipping collection')
                continue
            cur_fac_data = {}
            should_add = True
            for i, col_name in enumerate(data_columns):
                txt = cells[i].get_text(strip=True)
                if not txt:
                    should_add = False
                    break
                cur_fac_data[col_name] = txt
            if should_add:
                res.append(cur_fac_data)

    return res

# %%
import json
branches = ['biomed', 'biotech', 'chemical', 'cse', 'electrical', 'electronics', 'it', 'mechanical', 'mining', 'meta']
data_dir = '/home/sagar/python/rag-tutorial/minor-project/data/faculty-data'
for branch in branches:
    url = f'https://nitrr.ac.in/about{branch}.php'
    res = extract_faculty_info(url)
    if not res:
        print(f'failed to extract data for branch {branch}')
        continue
    with open(f'{data_dir}/{branch}.json', 'w+') as file:
        file.write(json.dumps(res))
    print(f'extracted data for branch {branch}')
# Out:
# got data from url https://nitrr.ac.in/aboutbiomed.php
# found 6 facutly tables
# found heading column for table 4
# found heading column for table 5
# found heading column for table 6
# found heading column for table 7
# found heading column for table 8
# found heading column for table 9
# extracted data for branch biomed
# got data from url https://nitrr.ac.in/aboutbiotech.php
# found 6 facutly tables
# found heading column for table 2
# found heading column for table 3
# found heading column for table 4
# found heading column for table 5
# found heading column for table 6
# found heading column for table 7
# extracted data for branch biotech
# got data from url https://nitrr.ac.in/aboutchemical.php
# found 6 facutly tables
# found heading column for table 0
# found heading column for table 1
# found heading column for table 2
# found heading column for table 3
# found heading column for table 4
# found heading column for table 5
# extracted data for branch chemical
# got data from url https://nitrr.ac.in/aboutcse.php
# found 4 facutly tables
# found heading column for table 4
# found heading column for table 5
# found heading column for table 6
# found heading column for table 7
# extracted data for branch cse
# got data from url https://nitrr.ac.in/aboutelectrical.php
# found 4 facutly tables
# found heading column for table 6
# found heading column for table 7
# found heading column for table 8
# found heading column for table 9
# extracted data for branch electrical
# got data from url https://nitrr.ac.in/aboutelectronics.php
# found 4 facutly tables
# found heading column for table 4
# found heading column for table 5
# found heading column for table 6
# found heading column for table 7
# extracted data for branch electronics
# got data from url https://nitrr.ac.in/aboutit.php
# found 4 facutly tables
# found heading column for table 18
# found heading column for table 19
# found heading column for table 20
# found heading column for table 21
# extracted data for branch it
# got data from url https://nitrr.ac.in/aboutmechanical.php
# found 12 facutly tables
# found heading column for table 0
# found heading column for table 1
# len of data_columns: 6 != len of cells (1) of table 1. Skipping collection
# found heading column for table 2
# len of data_columns: 5 != len of cells (1) of table 2. Skipping collection
# found heading column for table 2
# len of data_columns: 5 != len of cells (1) of table 2. Skipping collection
# found heading column for table 2
# found heading column for table 3
# found heading column for table 4
# len of data_columns: 6 != len of cells (1) of table 4. Skipping collection
# found heading column for table 5
# len of data_columns: 5 != len of cells (1) of table 5. Skipping collection
# found heading column for table 5
# len of data_columns: 5 != len of cells (1) of table 5. Skipping collection
# found heading column for table 5
# found heading column for table 6
# found heading column for table 7
# found heading column for table 12
# found heading column for table 13
# found heading column for table 22
# found heading column for table 23
# extracted data for branch mechanical
# got data from url https://nitrr.ac.in/aboutmining.php
# found 6 facutly tables
# found heading column for table 6
# found heading column for table 7
# found heading column for table 8
# found heading column for table 9
# found heading column for table 10
# found heading column for table 11
# extracted data for branch mining
# got data from url https://nitrr.ac.in/aboutmeta.php
# found 6 facutly tables
# found heading column for table 2
# found heading column for table 3
# found heading column for table 4
# found heading column for table 5
# found heading column for table 6
# found heading column for table 7
# extracted data for branch meta

# %%
tables[23]
# Out:
# <table align="center" border="0" cellpadding="8" cellspacing="2" class="table table-bordered" width="90%">
# <tbody>
# <tr>
# <th class="title" style="text-align: justify;">Name</th>
# <!--   <th class="title">Qualification</th> -->
# <th class="title" style="text-align: justify;">Designation</th>
# <th class="title" style="text-align: justify;">Contact No. / E-mail</th>
# </tr>
# <tr>
# <td>
# <p style="text-align: left;"><img alt="" height="100" src="../it/Harshal Phiske.jpg" width="89"/><br/>Harshal Phiske</p>
# </td>
# <td style="text-align: left;">
# <p>Senior Technical Assistant <br/> (Regular)</p>
# </td>
# <td>
# <p style="text-align: left;">7898850027<br/>hphiske.it@nitrr.ac.in <br/>harshalphiske@gmail.com</p>
# <p style="text-align: left;"> </p>
# </td>
# </tr>
# <tr>
# <td>
# <p style="text-align: left;"><img alt="" height="113" src="../it/Harish Shakywar.jpg" width="89"/><br/>Harish Shakywar</p>
# </td>
# <td style="text-align: left;">Senior Technical Assistant <br/> (Regular)</td>
# <td>
# <p style="text-align: left;">7999807263 <br/>hshakywar.it@nitrr.ac.in</p>
# </td>
# </tr>
# <tr>
# <td>
# <p style="text-align: left;"><img alt="" height="113" src="../it/Deepak.jpg" width="88"/><br/>Deepak Sagar</p>
# </td>
# <td style="text-align: left;">Senior Technician<br/> (Regular)</td>
# <td>9993396818<br/>dsagar.it@nitrr.ac.in</td>
# </tr>
# <tr>
# <td>
# <p style="text-align: left;"><a href="../it/Yogesh_Meena.jpg" rel="noopener" target="_blank"><img alt="" height="117" src="../it/Yogesh_Meena.jpg" width="95"/></a></p>
# <p style="text-align: left;">Yogesh Meena</p>
# </td>
# <!-- <td>12th +ADCA + ITI(COPA.(Pursuing))</td> -->
# <td style="text-align: left;">Technician</td>
# <td>
# <p style="text-align: left;">6260079894<br/>ymeena.it@nitrr.ac.in</p>
# </td>
# </tr>
# <tr>
# <td>
# <p style="text-align: left;"><img height="93" src="Saff_Photoes/Information Technology/Mr.Sahare.jpg" width="93"/><br/>Sunit Sahare</p>
# </td>
# <!--  <td>Diploma in Electronics</td> -->
# <td style="text-align: left;">Technical Assistant(On Contract)</td>
# <td>
# <p style="text-align: left;">9406033804<br/>sunitrich@gmail.com</p>
# </td>
# </tr>
# <tr>
# <td>
# <p style="text-align: left;"><img height="100" src="Saff_Photoes/Information Technology/Mr.Porte.jpg" width="100"/><br/>Manoj Kumar Porte</p>
# </td>
# <!--  <td>BCA </td> -->
# <td style="text-align: left;">Technical Assistant(On Contract)</td>
# <td>
# <p style="text-align: justify;">9713666866<br/>manoj.porte@hotmail.com</p>
# </td>
# </tr>
# <tr>
# <td>
# <p style="text-align: left;"><img height="100" src="../it/Govind Prasad Sahu.jpg" width="100"/><br/>Govind Prasad Sahu</p>
# </td>
# <!-- <td>12th </td> -->
# <td style="text-align: left;">Peon(On Contract)</td>
# <td style="text-align: left;">8085561220</td>
# </tr>
# <tr>
# <td>
# <p style="text-align: left;"><img alt="" height="133" src="../it/Pradeep Kumar Maurya.jpg" width="101"/><br/>Pradeep Kumar Maurya</p>
# </td>
# <td style="text-align: left;">Daily Wages Employee (Skilled)</td>
# <td>
# <p style="text-align: left;">8960787835<br/>pradeepmaurya372@gmail.com</p>
# </td>
# </tr>
# <tr>
# <td>
# <p style="text-align: left;"><img alt="" height="126" src="../it/Webupdate Staff(1)(1).jpg" width="105"/><br/>Kamlesh Kumar Prajapati</p>
# </td>
# <td style="text-align: left;">Daily Wages Employee (Unskilled)</td>
# <td>
# <p style="text-align: left;">9753959336<br/>kamleshprajapati@gmail.com</p>
# </td>
# </tr>
# </tbody>
# </table>

# %%
tables[20]
# Out:
# <table align="center" border="0" cellpadding="8" cellspacing="2" class="table table-bordered" width="90%">
# <tbody>
# <tr>
# <th align="center" class="title" colspan="5" style="text-align: justify; width: 99.6158%;"><strong>Head of Department</strong></th>
# </tr>
# <tr>
# <th class="title" style="text-align: justify; width: 17.749%;"><strong>Name</strong></th>
# <th class="title" style="text-align: justify; width: 25.4787%;"><strong>Qualification</strong></th>
# <th class="title" style="text-align: justify; width: 11.1431%;"><strong>Designation</strong></th>
# <th class="title" style="text-align: justify; width: 15.0817%;"><strong>Contact No. / E-mail</strong></th>
# <th class="title" style="text-align: justify; width: 30.1633%;"><strong>Specialization / Area of Interest</strong></th>
# </tr>
# <tr>
# <td class="head" style="text-align: left; width: 17.749%;"><a href="viewdetails.php?q=it.spandey"><img alt="" height="132" src="../it/Dr. Spandey.jpg" width="96"/></a><a href="viewdetails.php?q=it.ssahu"><br/> </a><a href="viewdetails.php?q=it.spandey">Dr. Sudhakar Pandey</a></td>
# <td class="head" style="text-align: left; width: 25.4787%;">B.E. (Computer Science and Engineering), M. Tech. (Software Engineering), Ph. D.</td>
# <td class="head" style="text-align: left; width: 11.1431%;">Professor &amp; Head of Department</td>
# <td class="head" style="width: 15.0817%;">
# <p style="text-align: left;">7974763176<br/>9407627136<br/><a href="mailto:Spandey96@gmail.com">Spandey96@gmail.com</a><br/>Spandey.it@nitrr.ac.in</p>
# </td>
# <td class="head" style="text-align: left; width: 30.1633%;">Computer Organization, Computer Networks, Cellular and Mobile computing</td>
# </tr>
# </tbody>
# </table>

# %%
# find the table
table = soup.find("table", class_="table-borderd")

# extract rows
rows = table.find_all("tr")

# parse each row
for row in rows:
    cells = [cell.get_text(strip=True) for cell in row.find_all(["th", "td"])]
    print(cells)
# Out:
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 5
#       3 print(table)
#       4 # extract rows
# ----> 5 rows = table.find_all("tr")
#       7 # parse each row
#       8 for row in rows:
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
def extract_faculty_data
# Out:
#   Cell In[20], line 1
#     def extract_faculty_data
#                             ^
# SyntaxError: expected '('
